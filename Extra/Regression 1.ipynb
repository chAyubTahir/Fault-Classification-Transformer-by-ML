# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn import linear_model
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error

datas= pd.read_csv(r"C:\Users\ayub_\Desktop\new_case\normalized_Actual.csv")

# %%
datas.shape
# Out:
# (1994, 6)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(datas[['Mean_Squared_Error', 'Mean_Absolute_Error', 'Root_Mean_Squared_Error', 'Standard_Deviation', 'Median']],datas.Class)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.coef_
# Out:
# array([  -7.06397953,  175.44928364, -343.50759173,    1.70382095,
#        -175.44928364])

# %%
reg.intercept_
# Out:
# 174.85162327455976

# %%
y_pred = reg.predict([[0.527130003, 0.642990453, 0.64299104, 0.007919569, 0.357009547 ]])

# %%
reg.predict([[0.305350458, 0.478193686, 0.478219404, 0.076568875, 0.521806314 ]])
# Out:
# array([0.90129342])

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
y_true = [0] 
y_true = np.array(y_true)
type(y_true)
y_true
# Out:
# array([0])

# %%
mean_squared_error(y_true, y_pred)
# Out:
# 0.1974226537225263

# %%
sns.pairplot(datas, vars=['Mean_Squared_Error', 'Mean_Absolute_Error', 'Root_Mean_Squared_Error', 'Standard_Deviation', 'Median'], hue="Class", height=3);
# Out:
# C:\Users\ayub_\Miniconda3\envs\py3k\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

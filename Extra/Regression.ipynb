# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn import linear_model
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns

datas= pd.read_csv("D:\Actual_Indicators.csv")
data = pd.read_csv("D:\Fault_Indicators.csv")

# %%
df = pd.read_csv("Desktop\indicator_r.csv")
df.shape
# Out:
# (4418, 6)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['Mean_Squared_Error', 'Mean_Absolute_Error', 'Root_Mean_Squared_Error', 'Standard_Deviation', 'Median']],df.Class)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
reg.coef_
# Out:
# array([-5.88826481e-01,  2.44059132e+08, -5.71828888e+02,  2.17393335e+00,
#         2.44058560e+08])

# %%
reg.intercept_
# Out:
# -244058559.32972732

# %%
reg.predict([[0.285902951, 0.407788941, 0.407792513, 0.016178508, 0.592211059 ]])    #moderate deviation
# Out:
# array([0.44934514])

# %%
reg.predict([[0.404234984, 0.635548792, 0.635547002, 0.009881426, 0.364451208 ]])
# Out:
# array([0.48112699])

# %%
reg.predict([[0.415083436, 0.644177858, 0.644028145, 0.091974213, 0.355822142]])    #major deviation
# Out:
# array([0.74203643])

# %% [markdown]
# 0.285902951	0.407788941	0.407792513	0.016178508	0.592211059	0
# 0.357904218	0.530467772	0.53045908	0.010081545	0.469532228

# %%
df
# Out:
#       Mean_Squared_Error  Mean_Absolute_Error  Root_Mean_Squared_Error  \
# 0               0.201396             0.309191                 0.309204
# 1               0.208924             0.318460                 0.318473
# 2               0.216434             0.327604                 0.327616
# 3               0.223632             0.336274                 0.336284
# 4               0.230479             0.344438                 0.344447
# 5               0.237026             0.352170                 0.352178
# 6               0.243306             0.359520                 0.359527
# 7               0.249347             0.366531                 0.366538
# 8               0.255171             0.373236                 0.373242
# 9               0.260757             0.379619                 0.379624
# 10              0.266112             0.385694                 0.385699
# 11              0.271286             0.391523                 0.391528
# ...

# %%
df.hist()
plt.show()

# %%
scatter_matrix(df[['Mean_Squared_Error', 'Mean_Absolute_Error', 'Root_Mean_Squared_Error', 'Standard_Deviation', 'Median']], 
               figsize= (15,10))
plt.show()

# %%
scatter_matrix?

# %%
g = sns.PairGrid(df[['Mean_Squared_Error', 'Mean_Absolute_Error', 'Root_Mean_Squared_Error', 'Standard_Deviation', 'Median']], hue= 'Class')
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\envs\py3k\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-0b49b73224fa> in <module>()
# ...

# %%
datas = np.array(datas)

# %%
datas.shape
# Out:
# (999, 5)

# %%
min_max_scaler = preprocessing.MinMaxScaler()
datas_minmax = min_max_scaler.fit_transform(datas)
datas_minmax
# Out:
# array([[0.20139646, 0.30919065, 0.30920374, 0.02881407, 0.69080935],
#        [0.20892419, 0.31846012, 0.31847343, 0.02922071, 0.68153988],
#        [0.21643375, 0.32760403, 0.32761612, 0.02802774, 0.67239597],
#        ...,
#        [0.02606572, 0.05007213, 0.05007343, 0.00794717, 0.94992787],
#        [0.0278761 , 0.05337649, 0.05338011, 0.01273179, 0.94662351],
#        [0.03073149, 0.05854627, 0.05855504, 0.01962915, 0.94145373]])

# %% [markdown]
# normalized_Actual = preprocessing.normalize(datas)

# %%
np.savetxt("normalized_Actual.csv", datas_minmax, delimiter=",")

# %%
data = np.array(data)

# %%
data.shape
# Out:
# (999, 5)

# %%
min_max_scaler = preprocessing.MinMaxScaler()
data_minmax = min_max_scaler.fit_transform(data)
data_minmax
# Out:
# array([[0.24425819, 0.4121106 , 0.41210343, 0.02530575, 0.5878894 ],
#        [0.24979934, 0.41838167, 0.41838191, 0.04156487, 0.58161833],
#        [0.25667205, 0.42608474, 0.42608461, 0.04085766, 0.57391526],
#        ...,
#        [0.00630685, 0.019638  , 0.01965802, 0.04676362, 0.980362  ],
#        [0.00287904, 0.00911901, 0.00918148, 0.06624049, 0.99088099],
#        [0.        , 0.        , 0.        , 0.03155953, 1.        ]])

# %%
np.savetxt("normalized_Fault.csv", data_minmax, delimiter=",")

# %%
df = pd.read_csv("E:\Thesis\normalized_Actual.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-1a50054a5406> in <module>()
# ----> 1 df = pd.read_csv("E:\Thesis\normalized_Actual.csv")
#
# ~\Miniconda3\envs\py3k\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
sns.pairplot(df, vars=['Mean_Squared_Error', 'Mean_Absolute_Error', 'Root_Mean_Squared_Error', 'Standard_Deviation', 'Median'], hue="Class", height=3);
# Out:
# C:\Users\ayub_\Miniconda3\envs\py3k\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
f = sns.PairGrid(df, vars=['Mean_Squared_Error', 'Mean_Absolute_Error', 'Root_Mean_Squared_Error', 'Standard_Deviation', 'Median'], hue='Class' ,palette="Set2")
f.map(plt.scatter);

# %%
data
# Out:
#      Mean_Squared_Error  Mean_Absolute_Error  Root_Mean_Squared_Error  \
# 0           1927.438647            43.902293                43.902604
# 1           1965.813209            44.336676                44.337492
# 2           2013.409348            44.870250                44.871030
# 3           2059.591941            45.382054                45.382727
# 4           2103.422957            45.862497                45.863089
# 5           2145.281410            46.316655                46.317183
# 6           2185.435230            46.748165                46.748639
# 7           2224.138590            47.160343                47.160774
# 8           2261.546887            47.555331                47.555724
# 9           2297.711169            47.934088                47.934447
# 10          2332.785729            48.298589                48.298921
# 11          2366.871811            48.650201                48.650507
# ...
